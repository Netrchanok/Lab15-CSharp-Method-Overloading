// %% [markdown]
// # Lab 15 Exercise 3

// %% [markdown]
// ## Runtime polymorphism

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab15_Ex03
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var animalA = new Dog();
// var animalB = new Fish();
// var animalC = new Bird();
//
// animalA.Move();
// animalB.Move();
// animalC.Move();
//
// class Animal
// {
//    public virtual void Move()
//    {
//     WriteLine("Move successfully.");
//    }
// }
//
// class Dog:Animal
// {
//     public override void Move()
//     {
//         WriteLine($"{this.GetType()}: Running on the ground.");
//         base.Move();
//     }
// }
// class Fish: Animal
// {
//     public override void Move()
//     {
//         WriteLine($"{this.GetType()}: Swimming in the water.");
//         base.Move();
//     }
// }
//
// class Bird: Animal
// {
//     public override void Move()
//     {
//         WriteLine($"{this.GetType()}: Flying in the air.");
//         base.Move();
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab15_Ex03
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %%
using static System.Console;

var animalA = new Dog();
var animalB = new Fish();
var animalC = new Bird();

animalA.Move();
animalB.Move();
animalC.Move();

class Animal
{
   public virtual void Move()
   {
      WriteLine("Move successfully.");
   } 
}

class Dog : Animal
{
    public override void Move()
    {
        WriteLine($"{this.GetType().Name}: Running on the ground.");
        base.Move();
    }
}

class Fish : Animal
{
    public override void Move()
    {
        WriteLine($"{this.GetType().Name}: Swimming in the water.");
        base.Move();
    }
}

class Bird : Animal
{
    public override void Move()
    {
        WriteLine($"{this.GetType().Name}: Flying in the air.");
        base.Move();
    }
}
// Out:
// Dog: Running on the ground.
// Move successfully.
// Fish: Swimming in the water.
// Move successfully.
// Bird: Flying in the air.
// Move successfully.

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
// ```cmd
// dotnet run --project Lab15_Ex03
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Move() ถูก overridden ในคลาสที่สืบทอด (เช่น Dog, Fish, Bird) ทำให้เราสามารถเรียก method เดียวกันจากอ็อบเจ็กต์ต่างชนิดกันได้ (ในนี้คืออ็อบเจ็กต์ของ Dog, Fish, และ Bird) แต่ผลลัพธ์ที่ได้จะแตกต่างกันตามชนิดของอ็อบเจ็กต์นั้นๆ
